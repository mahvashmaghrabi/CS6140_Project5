# %%
import pandas as pd
data = pd.read_csv('day1prediction.csv')

# %%
data.head()
# Out:
#        Date    Close_DJI  Volume_DJI   mom_DJI  mom1_DJI  mom2_DJI  mom3_DJI  \
# 0  12/31/09  10428.04981    0.000000  0.000000  0.000000  0.000000  0.000000
# 1    1/4/10  10583.95996    0.000000  0.014951  0.000000  0.000000  0.000000
# 2    1/5/10  10572.01953    0.000000 -0.001128  0.014951  0.000000  0.000000
# 3    1/6/10  10573.67969    0.515598  0.000157 -0.001128  0.014951  0.000000
# 4    1/7/10  10606.86035    9.776045  0.003138  0.000157 -0.001128  0.014951
#
#    ROC_5_DJI  ROC_10_DJI  ROC_15_DJI  ...  Dollar index-F_SNP  \
# 0        0.0         0.0         0.0  ...               -0.08
# 1        0.0         0.0         0.0  ...               -0.59
# 2        0.0         0.0         0.0  ...                0.03
# 3        0.0         0.0         0.0  ...               -0.24
# 4        0.0         0.0         0.0  ...                0.58
#
#    Dollar index_SNP  wheat-F_SNP  XAG_SNP  XAU_SNP  DJI_next_day  \
# ...

# %% [markdown]
# ### K-Nearest Neighbors Classifier

# %%
from sklearn.model_selection import train_test_split
import numpy as np
train, test = train_test_split(data, test_size=0.2)
x_train = train.loc[:,'Close_DJI':'XAU_SNP']
y_train = train.loc[:,'DJI_next_day':'SNP_next_day']

x_test = test.loc[:,'Close_DJI':'XAU_SNP']
y_test = test.loc[:,'DJI_next_day':'SNP_next_day']

from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(x_train, y_train)
neigh.predict(x_test)
# Out:
# array([['Down', 'Down', 'Down', 'Up', 'Down'],
#        ['Up', 'Up', 'Up', 'Up', 'Up'],
#        ['Down', 'Down', 'Down', 'Down', 'Down'],
#        ...,
#        ['Up', 'Down', 'Down', 'Down', 'Down'],
#        ['Down', 'Down', 'Down', 'Down', 'Down'],
#        ['Down', 'Down', 'Down', 'Down', 'Down']], dtype=object)

# %%
y_pred = neigh.predict(x_test)

accuracy = [0]*5

for i in range(len(y_test)):
    for j in range(5):
        if y_test[i][j] == y_pred[i][j]:
            accuracy[j]+=1

accuracy = [(x*1.0/len(y_test))*100 for x in accuracy]
print(accuracy)
# Out:
# [54.15617128463476, 56.67506297229219, 51.13350125944584, 51.13350125944584, 51.88916876574308]

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dec_tree_clf = DecisionTreeClassifier(random_state=0)
dec_tree_clf.fit(x_train, y_train)
y_pred_dt = dec_tree_clf.predict(x_test)

accuracy = [0]*5

for i in range(len(y_test)):
    for j in range(5):
        if y_test[i][j] == y_pred_dt[i][j]:
            accuracy[j]+=1

accuracy = [(x*1.0/len(y_test))*100 for x in accuracy]
print(accuracy)
# Out:
# [52.39294710327456, 51.88916876574308, 47.3551637279597, 48.86649874055416, 48.86649874055416]
